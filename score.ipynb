# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
def count_group(df):

    q1 = df['count'].quantile(0.75) # 하위 25%
    q2 = df['count'].quantile(0.5)  # 하위 50%
    q3 = df['count'].quantile(0.25) # 하위 75%

    # Group 칼럼 생성
    def count_group(count):
        if count >= q1:
            return 'A'
        elif count >= q2:
            return 'B'
        elif count >= q3:
            return 'C'
        else:
            return 'D'

    df['Group'] = df['count'].apply(count_group)
    
    
    # Score 칼럼 생성 함수
    def assign_score(group):
        if group == 'A':
            return 10
        elif group == 'B':
            return 8
        elif group == 'C':
            return 6
        else:
            return 4
    
    # Score 칼럼 생성
    df['score'] = df['Group'].apply(assign_score)
    return df


df_countn = [df1, df2, df3]
for df in df_count
    df = count_group(df)

# %%
def count_per_population_group(df):

    q1 = df['count_per_population'].quantile(0.75) # 하위 25%
    q2 = df['count_per_population'].quantile(0.5)  # 하위 50%
    q3 = df['count_per_population'].quantile(0.25) # 하위 75%

    # Group 칼럼
    def count_population_group(count_per_population):
        if count_per_population >= q1:
            return 'A'
        elif count_per_population >= q2:
            return 'B'
        elif count_per_population >= q3:
            return 'C'
        else:
            return 'D'

    df['Group'] = df['count_per_population'].apply(count_population_group)
    
    
    # Score 칼럼
    def assign_score(group):
        if group == 'A':
            return 10
        elif group == 'B':
            return 8
        elif group == 'C':
            return 6
        else:
            return 4
    
    df['score'] = df['Group'].apply(assign_score)
    return df


df_count_per_population = [df1, df2, df3]
for df in df_count_per_population:
    df = count_per_population_group(df)

# %%
def count_per_area_group(df):

    q1 = df['count_per_area'].quantile(0.75) # 하위 25%
    q2 = df['count_per_area'].quantile(0.5)  # 하위 50%
    q3 = df['count_per_area'].quantile(0.25) # 하위 75%

    # Group 칼럼 생성
    def count_area_group(count_per_area):
        if count_per_area >= q1:
            return 'A'
        elif count_per_area >= q2:
            return 'B'
        elif count_per_area >= q3:
            return 'C'
        else:
            return 'D'

    df['Group'] = df['count_per_area'].apply(count_area_group)
    
    
    # Score 칼럼
    def assign_score(group):
        if group == 'A':
            return 10
        elif group == 'B':
            return 8
        elif group == 'C':
            return 6
        else:
            return 4
    
    df['score'] = df['Group'].apply(count_area_group)
    return df


df_count_per_area = [df1, df2, df3]
for df in df_count_per_area:
    df = count_per_group(df)
